# %% [markdown]
# # Assignment Segmenting and Clustering Toronto Part 1

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
# import the URL library 
import urllib.request
# import the BeautifulSoup library 
from bs4 import BeautifulSoup

# %% [markdown]
# ### Scrape the data from the Wiki page

# %%
# specify the URL/web page for scraping
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
# open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)
# parse the HTML from our URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page, "lxml")

# use the 'find' function to call the table element
table=soup.find("table")

# get the information from the table row by row and save it into arrays
postalcode=[]
borough=[]
neigbour=[]

for row in table.find_all('tr'):
    col = row.find_all('td')
    if len(col)==3:
        postalcode.append(col[0].find(text=True))
        borough.append(col[1].find(text=True))
        neigbour.append(col[2].find(text=True))

# %% [markdown]
# ### Create a data frame from the scraped data

# %%
# create a data frame from the scraped data
df_toronto = pd.DataFrame(postalcode,columns=['PostalCode'])
df_toronto['Borough']=borough
df_toronto['Neighborhood']=neigbour

df_toronto.head()
# Out:
#   PostalCode            Borough                 Neighborhood
# 0       M1A
#       Not assigned
#
#
# 1       M2A
#       Not assigned
#
#
# 2       M3A
#         North York
#                    Parkwoods
#
# 3       M4A
#         North York
#             Victoria Village
#
# 4       M5A
#   Downtown Toronto
#   Regent Park / Harbourfront

# %% [markdown]
# ### Clean the dataset

# %%
# remove the cells which content "Not assigned" in column Borough
# for some reason the "Not assigned" has attached a command for new line "\n". Therefore, the content search was changed to "Not assigned\n"
df_toronto.drop(df_toronto[df_toronto['Borough']=='Not assigned\n'].index, inplace = True)
df_toronto.reset_index(drop=True, inplace=True)

# group the data by the postal code and join the neighborhoods with the same postal code, separated by comma
# the command for applying comma between the listed neighborhoods did not work very well and code displayed instead this "/" as a separator
df_toronto.groupby(['PostalCode', 'Borough'])['Neighborhood'].apply(lambda x:', '.join(x)).reset_index()

# if there are not assigned neihgborhood to a borough than the neighborhood takes the name from the borough
df_toronto['Neighborhood'].replace('Not assigned\n',df_toronto['Borough'],inplace=True)

df_toronto
# Out:
#     PostalCode            Borough  \
# 0         M3A
#         North York
#
# 1         M4A
#         North York
#
# 2         M5A
#   Downtown Toronto
#
# 3         M6A
#         North York
#
# 4         M7A
#   Downtown Toronto
#
# 5         M9A
#          Etobicoke
#
# 6         M1B
#        Scarborough
#
# 7         M3B
#         North York
#
# 8         M4B
#          East York
#
# 9         M5B
#   Downtown Toronto
#
# 10        M6B
#         North York
#
# 11        M9B
#          Etobicoke
#
# 12        M1C
#        Scarborough
#
# 13        M3C
#         North York
#
# 14        M4C
#          East York
#
# 15        M5C
#   Downtown Toronto
#
# 16        M6C
#               York
#
# 17        M9C
#          Etobicoke
#
# 18        M1E
#        Scarborough
#
# 19        M4E
#       East Toronto
#
# 20        M5E
#   Downtown Toronto
#
# 21        M6E
#               York
#
# 22        M1G
#        Scarborough
#
# 23        M4G
#          East York
#
# 24        M5G
# ...

# %%
# shape of the dataset
df_toronto.shape
# Out:
# (103, 3)
